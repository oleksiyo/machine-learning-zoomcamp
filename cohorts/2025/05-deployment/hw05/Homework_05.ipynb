# %% [markdown]
# <a href="https://colab.research.google.com/github/oleksiyo/machine-learning-zoomcamp/blob/master/cohorts/2025/05-deployment/hw05/Homework_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 5. Deployment

# %% [markdown]
# ## Question 1

# %%
pip install uv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 47.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer: 0.9.6

# %% [markdown]
# ## Question 2

# %%
uv add scikit-learn==1.6.1
# Out:
#   File "/tmp/ipython-input-3415262933.py", line 1
#     uv add scikit-learn==1.6.1
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer: b4fc2525eca2c69a59260f583c56a7557c6ccdf8deafdba6e060f94c1c59738e

# %% [markdown]
# ## Models

# %%
# !wget https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Out:
# --2025-10-31 16:44:53--  https://github.com/DataTalksClub/machine-learning-zoomcamp/raw/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin [following]
# --2025-10-31 16:44:53--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/refs/heads/master/cohorts/2025/05-deployment/pipeline_v1.bin
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1300 (1.3K) [application/octet-stream]
# ...

# %%
import pickle

# %%
input_file = 'pipeline_v1.bin'
with open(input_file, 'rb') as f_in:
    dv, model = pickle.load(f_in)

# %%
model
# Out:
# LogisticRegression(solver='liblinear')

# %% [markdown]
# ## Question 3

# %%
# 2. Define a new record
lead = {
    "lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0
}

# %%
X = dv.transform([lead])
y_pred = model.predict_proba(X)[0, 1]
print('input:', lead)
print('output:', y_pred)
# Out:
# input: {'lead_source': 'paid_ads', 'number_of_courses_viewed': 2, 'annual_income': 79276.0}
# output: 0.5336072702798061

# %% [markdown]
# Answer: 0.53

# %% [markdown]
# ## Question 4

# %% [markdown]
# Answer: 0.534

# %% [markdown]
# ## Question 5

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer: 121 MB

# %% [markdown]
# ## Question 6

# %% [markdown]
# {'convert_probability': 0.9933071490756734, 'converted': True}

# %% [markdown]
# Answer: 0.99
